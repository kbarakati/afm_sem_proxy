# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](
# https://colab.research.google.com/github/kbarakati/afm_sem_proxy/blob/main/main.ipynb
# )

# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle

# %%
! gdown --id 1ikbVUb2yw5f5wnxRTzwkf1fPTM5gLrOs
! gdown --id 14_4yQ7wV6uAPN_sJEj9pzdhjeLYKNezv
! gdown --id 1uG0cuDgQoTkC8Yz4jVtZ3j-uHy29rNwy

# %%
afm_array = np.load("afm_array.npy", allow_pickle=True)
sem_array = np.load("sem_array.npy", allow_pickle=True)
positions = np.load("common_locations.npy", allow_pickle=True)

# %%
i = 12  # index to inspect

afm_img = np.asarray(afm_array[i], dtype=float)
sem_img = np.asarray(sem_array[i], dtype=float)

fig, axes = plt.subplots(1, 2, figsize=(8, 4))

axes[0].imshow(afm_img, cmap="gray")
axes[0].set_title("AFM")
axes[0].axis("off")

axes[1].imshow(sem_img, cmap="gray")
axes[1].set_title("SEM")
axes[1].axis("off")

plt.tight_layout()
plt.show()
